# %%
from bs4 import BeautifulSoup

# %%
import requests
page = requests.get('https://jagokata.com/peribahasa/')
bs = BeautifulSoup(page.text, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
# <html lang="id"><head><script>var __ezHttpConsent={setByCat:function(src,tagType,attributes,category,force){var setScript=function(){if(force||window.ezTcfConsent[category]){var scriptElement=document.createElement(tagType);scriptElement.src=src;attributes.forEach(function(attr){for(var key in attr){if(attr.hasOwnProperty(key)){scriptElement.setAttribute(key,attr[key]);}}});var firstScript=document.getElementsByTagName(tagType)[0];firstScript.parentNode.insertBefore(scriptElement,firstScript);}};if(force||(window.ezTcfConsent&&window.ezTcfConsent.loaded)){setScript();}else if(typeof getEzConsentData==="function"){getEzConsentData().then(function(ezTcfConsent){if(ezTcfConsent&&ezTcfConsent.loaded){setScript();}else{console.error("cannot get ez consent data");force=true;setScript();}});}else{force=true;setScript();console.error("getEzConsentData is not a function");}},};</script>
# ...

# %%
bs.title
# Out:
# <title>Lebih dari 2.000 peribahasa yang terbaik dan terkenal- JagoKata.com</title>

# %%
bs.title.string
# Out:
# 'Lebih dari 2.000 peribahasa yang terbaik dan terkenal- JagoKata.com'

# %%
bs.title.name
# Out:
# 'title'

# %%
bs.find_all('span')
# Out:
# [<span class="copyright">(c) 2016-2024 JagoKata</span>]

# %%
bs.find_all('div')
# Out:
# [<div class="hidezoek citatennet" id="top">
#  <div class="inner">
#  <div id="logo">
#  <a href="/" title="jagokata.com kata bijak, kata mutiara, kutipan dan ucapan terkenal ">
#  <img alt="jagokata.com kata bijak, kata mutiara, kutipan dan ucapan terkenal " height="40" src="https://jagokata.com/images/logo-kata2.png" width="180"/>
#  </a>
#  <button aria-label="Toggle searchform" class="menu" id="search-toggle"><img alt="toggle zoekform" src="images/ic_action_search.png"/></button>
#  <button aria-label="Menu" class="menu" id="menu-toggle"></button>
#  </div>
#  <ol id="navigation">
#  <li><a href="kata-bijak/"><i class="fa fa-quote-right"></i>Kata Bijak</a></li>
#  <li><a href="arti-kata/"><i class="fa fa-book"></i>Arti Kata</a></li>
#  <li><a href="peribahasa/"><i class="fa fa-comment"></i>Peribahasa</a></li>
#  <li><a href="games/wordle.html"><i class="fa fa-game"></i>Wordle</a></li>
#  </ol>
#  <div id="lightdark">
# ...

# %%
bs.find("head")
# Out:
# <head><script>var __ezHttpConsent={setByCat:function(src,tagType,attributes,category,force){var setScript=function(){if(force||window.ezTcfConsent[category]){var scriptElement=document.createElement(tagType);scriptElement.src=src;attributes.forEach(function(attr){for(var key in attr){if(attr.hasOwnProperty(key)){scriptElement.setAttribute(key,attr[key]);}}});var firstScript=document.getElementsByTagName(tagType)[0];firstScript.parentNode.insertBefore(scriptElement,firstScript);}};if(force||(window.ezTcfConsent&&window.ezTcfConsent.loaded)){setScript();}else if(typeof getEzConsentData==="function"){getEzConsentData().then(function(ezTcfConsent){if(ezTcfConsent&&ezTcfConsent.loaded){setScript();}else{console.error("cannot get ez consent data");force=true;setScript();}});}else{force=true;setScript();console.error("getEzConsentData is not a function");}},};</script>
# ...

# %%
bs.find("div")
# Out:
# <div class="hidezoek citatennet" id="top">
# <div class="inner">
# <div id="logo">
# <a href="/" title="jagokata.com kata bijak, kata mutiara, kutipan dan ucapan terkenal ">
# <img alt="jagokata.com kata bijak, kata mutiara, kutipan dan ucapan terkenal " height="40" src="https://jagokata.com/images/logo-kata2.png" width="180"/>
# </a>
# <button aria-label="Toggle searchform" class="menu" id="search-toggle"><img alt="toggle zoekform" src="images/ic_action_search.png"/></button>
# <button aria-label="Menu" class="menu" id="menu-toggle"></button>
# </div>
# <ol id="navigation">
# <li><a href="kata-bijak/"><i class="fa fa-quote-right"></i>Kata Bijak</a></li>
# <li><a href="arti-kata/"><i class="fa fa-book"></i>Arti Kata</a></li>
# <li><a href="peribahasa/"><i class="fa fa-comment"></i>Peribahasa</a></li>
# <li><a href="games/wordle.html"><i class="fa fa-game"></i>Wordle</a></li>
# </ol>
# <div id="lightdark">
# ...

# %%
bs.find("span")
# Out:
# <span class="copyright">(c) 2016-2024 JagoKata</span>

# %%
bs.find_all("span")
# Out:
# [<span class="copyright">(c) 2016-2024 JagoKata</span>]

# %%
for string in bs.stripped_strings:
    print(repr(string))
# Out:
# 'Lebih dari 2.000 peribahasa yang terbaik dan terkenal- JagoKata.com'
# 'Kata Bijak'
# 'Arti Kata'
# 'Peribahasa'
# 'Wordle'
# 'Cari'
# 'Peribahasa'
# 'Kata kunci Peribahasa yang popular'
# 'anak'
# 'ayam'
# 'gula'
# 'harimau'
# 'hidup'
# 'ikan'
# 'jahat'
# 'lemah'
# 'manis'
# 'marah'
# 'melawan'
# 'menyembunyikan'
# 'miskin'
# 'mulut'
# 'rajin'
# 'tangan'
# 'telinga'
# 'terbalik'
# 'udang'
# 'untung'
# 'Semua kata kunci'
# 'Kata kunci Peribahasa'
# 'mulut'
# 'padi'
# 'tangan'
# 'ikan'
# 'hidup'
# 'hidung'
# 'hujan'
# 'hitam'
# 'mata'
# 'tikus'
# 'anak'
# 'makan'
# 'Kata Bijak'
# 'Top 100'
# 'Acak'
# 'Tokoh'
# 'Kata kunci'
# 'Arti Kata'
# 'Daftar Kata'
# 'Acak'
# 'Peribahasa'
# 'Daftar Kata'
# 'Acak'
# 'Games'
# 'Wordle'
# 'Privasi'
# 'Kontak'
# '(c) 2016-2024 JagoKata'
# 'Pemblokir iklan aktif.'
# 'Oh tidak. Anda menggunakan pemblokir iklan. Bisakah Anda menonaktifkan ini untuk JagoKata.com?'
# ...

# %%
bs.find_all('a')
# Out:
# [<a href="/" title="jagokata.com kata bijak, kata mutiara, kutipan dan ucapan terkenal ">
#  <img alt="jagokata.com kata bijak, kata mutiara, kutipan dan ucapan terkenal " height="40" src="https://jagokata.com/images/logo-kata2.png" width="180"/>
#  </a>,
#  <a href="kata-bijak/"><i class="fa fa-quote-right"></i>Kata Bijak</a>,
#  <a href="arti-kata/"><i class="fa fa-book"></i>Arti Kata</a>,
#  <a href="peribahasa/"><i class="fa fa-comment"></i>Peribahasa</a>,
#  <a href="games/wordle.html"><i class="fa fa-game"></i>Wordle</a>,
#  <a href="https://jagokata.com/peribahasa/anak.html">anak</a>,
#  <a href="https://jagokata.com/peribahasa/ayam.html">ayam</a>,
#  <a href="https://jagokata.com/peribahasa/gula.html">gula</a>,
#  <a href="https://jagokata.com/peribahasa/harimau.html">harimau</a>,
#  <a href="https://jagokata.com/peribahasa/hidup.html">hidup</a>,
#  <a href="https://jagokata.com/peribahasa/ikan.html">ikan</a>,
# ...

# %%
list_items = bs.find_all('a')
for li in list_items:
    print(li.text)
# Out:
# Kata Bijak
# Arti Kata
# Peribahasa
# Wordle
# celur
# celur
# celuran
# mencelur
# penceluran
# Arti kata anak
# Arti kata batu
# Arti kata ilmu
# Arti kata makan
# Arti kata uang
# Arti kata angin
# Top 100
# Acak
# Tokoh
# Kata kunci
# Daftar Kata
# Acak
# Daftar Kata
# Acak
# Wordle
# Privasi
# Kontak

# %%
page = requests.get('https://jagokata.com/arti-kata/anak.html')
bs = BeautifulSoup(page.text, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
# <html lang="id"><head><script>var __ezHttpConsent={setByCat:function(src,tagType,attributes,category,force){var setScript=function(){if(force||window.ezTcfConsent[category]){var scriptElement=document.createElement(tagType);scriptElement.src=src;attributes.forEach(function(attr){for(var key in attr){if(attr.hasOwnProperty(key)){scriptElement.setAttribute(key,attr[key]);}}});var firstScript=document.getElementsByTagName(tagType)[0];firstScript.parentNode.insertBefore(scriptElement,firstScript);}};if(force||(window.ezTcfConsent&&window.ezTcfConsent.loaded)){setScript();}else if(typeof getEzConsentData==="function"){getEzConsentData().then(function(ezTcfConsent){if(ezTcfConsent&&ezTcfConsent.loaded){setScript();}else{console.error("cannot get ez consent data");force=true;setScript();}});}else{force=true;setScript();console.error("getEzConsentData is not a function");}},};</script>
# ...

# %%
bs.find_all('p')
# Out:
# [<p>Contoh kata anak adalah: ini bukan <strong>anak</strong>nya, melainkan cucunya.</p>,
#  <p>Kata anak adalah <em>Kata Nomina (kata benda)</em>.</p>,
#  <p class="leftpadding">keturunan Adam; manusia;</p>,
#  <p class="leftpadding">gelar bangsawan (golongan atau kasta ksatria);</p>,
#  <p class="leftpadding">selokan; sungai kecil;</p>,
#  <p class="leftpadding">anak kecil yang sudah mampu menguasai kepandaian yang dimiliki oleh orang dewasa;</p>,
#  <p class="leftpadding">anak yang ketiga;</p>,
#  <p class="leftpadding">gelar untuk Yesus Kristus yang menyatakan bahwa Ia berasal dari Allah dan melakukan penyelamatan manusia;</p>,
#  <p class="leftpadding">anak haram jadah;</p>,
#  <p class="leftpadding">anak gadis yang dikurung atau dipingit beberapa waktu sebelum dinikahkan;</p>,
#  <p class="leftpadding">angin sepoi-sepoi; angin lembut;</p>,
#  <p class="leftpadding">anak orang lain yang diambil (dipelihara) serta disahkan secara hukum sebagai anak sendiri;</p>,
# ...

# %%
list_items = bs.find_all('p')
for li in list_items:
    print(li.text)
# Out:
# Contoh kata anak adalah: ini bukan anaknya, melainkan cucunya.
# Kata anak adalah Kata Nomina (kata benda).
# keturunan Adam; manusia;
# gelar bangsawan (golongan atau kasta ksatria);
# selokan; sungai kecil;
# anak kecil yang sudah mampu menguasai kepandaian yang dimiliki oleh orang dewasa;
# anak yang ketiga;
# gelar untuk Yesus Kristus yang menyatakan bahwa Ia berasal dari Allah dan melakukan penyelamatan manusia;
# anak haram jadah;
# anak gadis yang dikurung atau dipingit beberapa waktu sebelum dinikahkan;
# angin sepoi-sepoi; angin lembut;
# anak orang lain yang diambil (dipelihara) serta disahkan secara hukum sebagai anak sendiri;
# anak yang diberi biaya pendidikan (oleh seseorang ), tetapi tetap tinggal pada orang tuanya;
# baju dalam;
# anak yang selalu mengganggu anak orang lain;
# sepasang (seorang laki-laki dan perempuan); sejoli;
# anak negeri;
# anak yang terlalu disayangi oleh bapaknya sehingga tidak sempat bergaul dengan anak-anak yang lain;
# ...

# %%
page = requests.get('https://jagokata.com/arti-kata/ayam.html')
bs = BeautifulSoup(page.text, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
# <html lang="id"><head><script>var __ezHttpConsent={setByCat:function(src,tagType,attributes,category,force){var setScript=function(){if(force||window.ezTcfConsent[category]){var scriptElement=document.createElement(tagType);scriptElement.src=src;attributes.forEach(function(attr){for(var key in attr){if(attr.hasOwnProperty(key)){scriptElement.setAttribute(key,attr[key]);}}});var firstScript=document.getElementsByTagName(tagType)[0];firstScript.parentNode.insertBefore(scriptElement,firstScript);}};if(force||(window.ezTcfConsent&&window.ezTcfConsent.loaded)){setScript();}else if(typeof getEzConsentData==="function"){getEzConsentData().then(function(ezTcfConsent){if(ezTcfConsent&&ezTcfConsent.loaded){setScript();}else{console.error("cannot get ez consent data");force=true;setScript();}});}else{force=true;setScript();console.error("getEzConsentData is not a function");}},};</script>
# ...

# %%
bs.find_all('p')
# Out:
# [<p><strong>Arti:</strong> unggas yang pada umumnya tidak dapat terbang, dapat dijinakkan dan dipelihara, berjengger, yang jantan berkokok dan bertaji, sedangkan yang betina berkotek;</p>,
#  <p>Kata ayam adalah <em>Kata Nomina (kata benda)</em>.</p>,
#  <p class="leftpadding">ayam jantan yang mampu bersuara indah dan panjang (sering diperlombakan di Jawa Barat);</p>,
#  <p class="leftpadding">ayam potong yang sudah bersih tanpa jeroan, kaki, leher, dan kepala, siap untuk dimasak;</p>,
#  <p class="leftpadding">ayam yang tidak berekor;</p>,
#  <p class="leftpadding">ayam sabung yang tidak bertaji;</p>,
#  <p class="leftpadding">ayam kampung;</p>,
#  <p class="leftpadding">ayam jantan yang biasa disabung; ayam aduan;</p>,
#  <p class="leftpadding">ayam yang biasa dipiara secara dilepaskan;</p>,
#  <p class="leftpadding">ayam jantan yang dipiara untuk diadu; ayam sabungan;</p>,
#  <p class="leftpadding">ayam yang dipiara untuk disembelih;</p>,
# ...

# %%
list_items = bs.find_all('p')
for li in list_items:
    print(li.text)
# Out:
# Arti: bercelur tangan;
# Arti: ada tangannya; mempunyai tangan;contoh: 'pembunuhan itu terjadi karena adanya campur tangan bertangan siluman'
# Arti: perihal dari tangan ke tangan; perihal tidak langsung dari sumbernya (asalnya);
# Arti: dapat ditangani; dapat diselesaikan; dapat digarapcontoh: 'sampai sekarang masalah itu belum tertangani'
# Arti: proses, cara, perbuatan menangani; penggarapancontoh: 'penanganan kasus itu terkesan lambat'
# Kata tangan adalah Kata Nomina (kata benda).
# jari tangan;
# bagasi jinjing
# saling berpegangan tangancontoh: pengantin baru itu berjalan sambil bergandeng tangan tangan
# menepuk-nepukkan tangan seperti ketika memukul gendang;
# tidak mengerjakan; tidak turut melakukan;
# berkepit;
# bertadah amin;
# berpegangan (bergandengan, berjabatan) tangan;
# menamparkan kedua telapak tangan untuk mengadakan bunyi (tanda gembira, setuju, dsb);
# berteleku;
# ditulis dengan tangan (tidak dicetak);
# mempunyai pembantu; ada yang membantu (menolong);
# ...

# %%
page = requests.get('https://jagokata.com/arti-kata/bebek.html')
bs = BeautifulSoup(page.text, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
# <html lang="id"><head><script>var __ezHttpConsent={setByCat:function(src,tagType,attributes,category,force){var setScript=function(){if(force||window.ezTcfConsent[category]){var scriptElement=document.createElement(tagType);scriptElement.src=src;attributes.forEach(function(attr){for(var key in attr){if(attr.hasOwnProperty(key)){scriptElement.setAttribute(key,attr[key]);}}});var firstScript=document.getElementsByTagName(tagType)[0];firstScript.parentNode.insertBefore(scriptElement,firstScript);}};if(force||(window.ezTcfConsent&&window.ezTcfConsent.loaded)){setScript();}else if(typeof getEzConsentData==="function"){getEzConsentData().then(function(ezTcfConsent){if(ezTcfConsent&&ezTcfConsent.loaded){setScript();}else{console.error("cannot get ez consent data");force=true;setScript();}});}else{force=true;setScript();console.error("getEzConsentData is not a function");}},};</script>
# ...

# %%
bs.find_all('p')
# Out:
# [<p><strong>Arti:</strong> itik;</p>,
#  <p><strong>Arti:</strong> embik (tiruan bunyi kambing);</p>,
#  <p>Seseorang mengucapkan bebek sebagai berikut: bébék.</p>,
#  <p>Kata bebek adalah <em>Kata Nomina (kata benda)</em>, <em>Minangkabau</em>.</p>,
#  <p class="leftpadding">rujak yang bahannya ditumbuk sampai lumat; rujak tumbuk;</p>,
#  <p class="leftpadding">sendok bergagang pendek, bagian depannya lebih cekung daripada sendok biasa, bentuknya seperti paruh bebek (biasanya untuk menyendok bubur);</p>,
#  <p><span>Tip</span>: doubleclick kata di atas untuk mencari cepat</p>,
#  <p>Database utama KBBI merupakan Hak Cipta Badan Pengembangan dan Pembinaan Bahasa, Kemdikbud (Pusat Bahasa)</p>,
#  <p>Situs kata-kata terbesar di Indonesia.</p>,
# ...

# %%
list_items = bs.find_all('p')
for li in list_items:
    print(li.text)
# Out:
# Arti: itik;
# Arti: embik (tiruan bunyi kambing);
# Seseorang mengucapkan bebek sebagai berikut: bébék.
# Kata bebek adalah Kata Nomina (kata benda), Minangkabau.
# rujak yang bahannya ditumbuk sampai lumat; rujak tumbuk;
# sendok bergagang pendek, bagian depannya lebih cekung daripada sendok biasa, bentuknya seperti paruh bebek (biasanya untuk menyendok bubur);
# Tip: doubleclick kata di atas untuk mencari cepat
# Database utama KBBI merupakan Hak Cipta Badan Pengembangan dan Pembinaan Bahasa, Kemdikbud (Pusat Bahasa)
# Situs kata-kata terbesar di Indonesia.
# Oh tidak. Anda menggunakan pemblokir iklan. Bisakah Anda menonaktifkan ini untuk JagoKata.com? Kami hanya menampilkan beberapa spanduk yang menarik perhatian untuk memastikan bahwa halaman ini ada dan pembuat halaman ini juga mendapatkan sesuatu atas karyanya. Terima kasih!

# %%
page = requests.get('https://jagokata.com/arti-kata/tangan.html')
bs = BeautifulSoup(page.text, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
# <html lang="id"><head><script>var __ezHttpConsent={setByCat:function(src,tagType,attributes,category,force){var setScript=function(){if(force||window.ezTcfConsent[category]){var scriptElement=document.createElement(tagType);scriptElement.src=src;attributes.forEach(function(attr){for(var key in attr){if(attr.hasOwnProperty(key)){scriptElement.setAttribute(key,attr[key]);}}});var firstScript=document.getElementsByTagName(tagType)[0];firstScript.parentNode.insertBefore(scriptElement,firstScript);}};if(force||(window.ezTcfConsent&&window.ezTcfConsent.loaded)){setScript();}else if(typeof getEzConsentData==="function"){getEzConsentData().then(function(ezTcfConsent){if(ezTcfConsent&&ezTcfConsent.loaded){setScript();}else{console.error("cannot get ez consent data");force=true;setScript();}});}else{force=true;setScript();console.error("getEzConsentData is not a function");}},};</script>
# ...

# %%
bs.find_all('p')
# Out:
# [<p><strong>Arti:</strong> bercelur tangan;</p>,
#  <p><strong>Arti:</strong> ada tangannya; mempunyai tangan;<br/>contoh: <i>'pembunuhan itu terjadi karena adanya campur tangan <strong>bertangan</strong> siluman'</i></p>,
#  <p><strong>Arti:</strong> perihal dari tangan ke tangan; perihal tidak langsung dari sumbernya (asalnya);</p>,
#  <p><strong>Arti:</strong> dapat ditangani; dapat diselesaikan; dapat digarap<br/>contoh: <i>'sampai sekarang masalah itu belum <strong>tertangani</strong>'</i></p>,
#  <p><strong>Arti:</strong> proses, cara, perbuatan menangani; penggarapan<br/>contoh: <i>'<strong>penanganan</strong> kasus itu terkesan lambat'</i></p>,
#  <p>Kata tangan adalah <em>Kata Nomina (kata benda)</em>.</p>,
#  <p class="leftpadding">jari tangan;</p>,
#  <p class="leftpadding">bagasi jinjing</p>,
#  <p class="leftpadding">saling berpegangan tangan<br/>contoh: <i>pengantin baru itu berjalan sambil <strong>bergandeng tangan</strong> tangan</i></p>,
# ...

# %%
list_items = bs.find_all('p')
for li in list_items:
    print(li.text)
# Out:
# Arti: bercelur tangan;
# Arti: ada tangannya; mempunyai tangan;contoh: 'pembunuhan itu terjadi karena adanya campur tangan bertangan siluman'
# Arti: perihal dari tangan ke tangan; perihal tidak langsung dari sumbernya (asalnya);
# Arti: dapat ditangani; dapat diselesaikan; dapat digarapcontoh: 'sampai sekarang masalah itu belum tertangani'
# Arti: proses, cara, perbuatan menangani; penggarapancontoh: 'penanganan kasus itu terkesan lambat'
# Kata tangan adalah Kata Nomina (kata benda).
# jari tangan;
# bagasi jinjing
# saling berpegangan tangancontoh: pengantin baru itu berjalan sambil bergandeng tangan tangan
# menepuk-nepukkan tangan seperti ketika memukul gendang;
# tidak mengerjakan; tidak turut melakukan;
# berkepit;
# bertadah amin;
# berpegangan (bergandengan, berjabatan) tangan;
# menamparkan kedua telapak tangan untuk mengadakan bunyi (tanda gembira, setuju, dsb);
# berteleku;
# ditulis dengan tangan (tidak dicetak);
# mempunyai pembantu; ada yang membantu (menolong);
# ...
